# %%
import pandas as pd

# Load bond data
bond_data = pd.read_csv(r'C:\Users\Melanie\Desktop\optimization_engine\bond_data.csv')

# Summary statistics for OAS (Option-Adjusted Spread)
print("OAS Statistics:")
print(bond_data['OAS'].describe())

# Calculate the sum of absolute deviations from the benchmark weight for MaxRisk guidance
BenchmarkWeight = 0.01
max_risk_estimate = (bond_data['OAS'] * abs(BenchmarkWeight)).sum()

print(f"Estimated MaxRisk based on benchmark weights: {max_risk_estimate}")

# Summary statistics for liquidity score
print("\nLiquidity Score Statistics:")
liq = (bond_data['liquidity_score'] * abs(BenchmarkWeight)).sum()
print(liq)

# Summary statistics for duration (used in volume and DTS constraints)
print("\nDuration Statistics:")
print(bond_data['duration'].describe())

# Summary statistics for DTS (Duration Times Spread)
bond_data['DTS'] = bond_data['duration'] * bond_data['OAS']
dts = (bond_data['DTS'] * abs(BenchmarkWeight)).sum()
print("\nDTS Statistics:")
print(dts)
print(bond_data['DTS'].describe())

# costs 
bond_data['transaction_cost'] = bond_data['ask_price'] - bond_data['bid_price']
t_cost = (bond_data['transaction_cost'] * abs(BenchmarkWeight)).sum()
print(t_cost)
# Out:
# OAS Statistics:
# count    36500.000000
# mean      1061.991507
# std        928.239002
# min          1.000000
# 25%        330.000000
# 50%        728.000000
# 75%       1582.000000
# max       4575.000000
# Name: OAS, dtype: float64
# Estimated MaxRisk based on benchmark weights: 387626.89999999997
#
# Liquidity Score Statistics:
# 2031.0660999999998
#
# Duration Statistics:
# count    36500.000000
# mean         6.841742
# std          3.244490
# min          0.000000
# 25%          4.356493
# 50%          6.528530
# 75%          8.930026
# max         17.711061
# Name: duration, dtype: float64
#
# DTS Statistics:
# 2273631.934057838
# count    36500.000000
# mean      6229.128586
# std       4184.799268
# min          0.000000
# 25%       2502.288161
# 50%       5959.507543
# 75%       9642.949192
# max      24393.628774
# Name: DTS, dtype: float64
# 334.013

# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

bond_data = pd.read_csv(r'C:\Users\Melanie\Desktop\optimization_engine\bond_data.csv')

BenchmarkWeight = 0.01 

bond_data['transaction_cost'] = bond_data['ask_price'] - bond_data['bid_price']
bond_data['daily_return'] = bond_data['expected_return']
bond_data['DTS'] = bond_data['duration'] * bond_data['OAS']

N = 100 
lambda_1 = 10
lambda_2 = 20

model = gp.Model("DynamicCorporateBondOptimization")

w = model.addVars(N, vtype=GRB.CONTINUOUS, lb=0, name="w")  
x = model.addVars(N, vtype=GRB.BINARY, name="x")  # whether bond i is chosen

model.setObjective(
    gp.quicksum((bond_data.loc[i, 'expected_return'] * w[i] - bond_data.loc[i, 'transaction_cost'] * x[i]) for i in range(N))  # return minus transaction cost
    - lambda_1 * gp.quicksum(bond_data.loc[i, 'OAS'] * w[i] for i in range(N))  # OAS risk term
    - lambda_2 * gp.quicksum(bond_data.loc[i, 'DTS'] * w[i] for i in range(N)),  # DTS risk term
    GRB.MAXIMIZE
)

# Risk constraints
benchmark_OAS = 274.88 
lower_bound = 0.9 * benchmark_OAS
upper_bound = 1.1 * benchmark_OAS
model.addConstr(gp.quicksum(bond_data.loc[i, 'OAS'] * w[i] for i in range(N)) >= lower_bound, "MinOAS")
model.addConstr(gp.quicksum(bond_data.loc[i, 'OAS'] * w[i] for i in range(N)) <= upper_bound, "MaxOAS")

# Liquidity
Liquidity = gp.quicksum(bond_data.loc[i, 'liquidity_score'] * BenchmarkWeight for i in range(N))
MinLiquidity = 0.9 * Liquidity
model.addConstr(gp.quicksum(bond_data.loc[i, 'liquidity_score'] * w[i] for i in range(N)) >= MinLiquidity, "MinLiquidity")

# Transaction cost 
Benchmark_cost = gp.quicksum(bond_data.loc[i, 'transaction_cost'] * BenchmarkWeight for i in range(N))
lower_t_cost = 0.9 * Benchmark_cost
upper_t_cost = 1.1 * Benchmark_cost
model.addConstr(gp.quicksum(bond_data.loc[i, 'transaction_cost'] * x[i] for i in range(N)) >= lower_t_cost, "MintCost")
model.addConstr(gp.quicksum(bond_data.loc[i, 'transaction_cost'] * x[i] for i in range(N)) <= upper_t_cost, "MaxtCost")

# binary 
M = 100000
for i in range(N):
    model.addConstr(w[i] <= M * x[i], f"WeightSelection_{i}")

# sum of weights = 1
model.addConstr(gp.quicksum(w[i] for i in range(N)) == 1, "WeightSum")

model.optimize()

if model.status == GRB.OPTIMAL:
    print("Optimal solution found:")
    for i in range(N):
        print(f"Bond {bond_data.loc[i, 'ISIN']}: weight = {w[i].x:.4f}, chosen = {x[i].x:.0f}")
else:
    print("No optimal solution found.")

chosen_bonds = [bond_data.loc[i, 'ISIN'] for i in range(N) if x[i].x == 1]
if chosen_bonds:
    print("Chosen bonds:", chosen_bonds)
    #output weights of the chosen_bonds
    print("Weights of chosen bonds:", [w[i].x for i in range(N) if x[i].x == 1])
else:
    print("No bonds were chosen.")
    
#
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 106 rows, 200 columns and 800 nonzeros
# Model fingerprint: 0xbfdb25a0
# Variable types: 100 continuous, 100 integer (100 binary)
# Coefficient statistics:
#   Matrix range     [5e-02, 1e+05]
#   Objective range  [3e-01, 1e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e-01, 3e+02]
# Presolve removed 66 rows and 128 columns
# Presolve time: 0.00s
# Presolved: 40 rows, 72 columns, 215 nonzeros
# Variable types: 36 continuous, 36 integer (36 binary)
# Found heuristic solution: objective -62824.98035
# Found heuristic solution: objective -62499.87619
# Found heuristic solution: objective -22687.32503
#
# Root relaxation: objective -1.485186e+04, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -14851.858    0    2 -22687.325 -14851.858  34.5%     -    0s
# H    0     0                    -14851.86210 -14851.858  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 4: -14851.9 -22687.3 -62499.9 -62825
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.485186210355e+04, best bound -1.485185814125e+04, gap 0.0000%
# Optimal solution found:
# Bond XS6374626743: weight = 0.0000, chosen = 0
# Bond XS7725417514: weight = 0.0000, chosen = 0
# Bond XS0580263824: weight = 0.0000, chosen = 0
# Bond XS2648613818: weight = 0.0000, chosen = 0
# Bond XS4136720317: weight = 0.0000, chosen = 0
# Bond XS3155351137: weight = 0.0000, chosen = 0
# Bond XS6874147880: weight = 0.0000, chosen = 0
# Bond XS8687077207: weight = 0.0000, chosen = 0
# Bond XS2204686871: weight = 0.0000, chosen = 0
# Bond XS0667427520: weight = 0.0000, chosen = 0
# Bond XS2420466826: weight = 0.0000, chosen = 0
# Bond XS0334663625: weight = 0.0000, chosen = 0
# Bond XS1845368600: weight = 0.0000, chosen = 0
# Bond XS8838265784: weight = 0.0000, chosen = 0
# Bond XS0275783003: weight = 0.0000, chosen = 0
# Bond XS6120407001: weight = 0.0000, chosen = 0
# Bond XS1564002145: weight = 0.0000, chosen = 0
# Bond XS6367057431: weight = 0.0000, chosen = 0
# Bond XS5508523322: weight = 0.0000, chosen = 0
# Bond XS2363807617: weight = 0.0000, chosen = 0
# Bond XS0881626830: weight = 0.0000, chosen = 0
# Bond XS1044688222: weight = 0.7751, chosen = 1
# Bond XS3757073073: weight = 0.0000, chosen = 0
# Bond XS5732828111: weight = 0.0000, chosen = 0
# Bond XS5283030437: weight = 0.0000, chosen = 0
# Bond XS7620025655: weight = 0.0000, chosen = 0
# Bond XS5257140042: weight = 0.0000, chosen = 0
# Bond XS3200452847: weight = 0.0000, chosen = 0
# Bond XS0420346021: weight = 0.0000, chosen = 0
# Bond XS8527715611: weight = 0.0000, chosen = 0
# Bond XS0708566218: weight = 0.0000, chosen = 0
# Bond XS7683307261: weight = 0.0000, chosen = 0
# Bond XS1652855035: weight = 0.0000, chosen = 0
# Bond XS5407446353: weight = 0.0000, chosen = 0
# Bond XS2673120726: weight = 0.0000, chosen = 0
# Bond XS4468400158: weight = 0.0000, chosen = 0
# Bond XS7406456224: weight = 0.0000, chosen = 0
# Bond XS5840344630: weight = 0.0000, chosen = 0
# Bond XS4654313207: weight = 0.0000, chosen = 0
# Bond XS4376103712: weight = 0.0000, chosen = 0
# Bond XS0024200712: weight = 0.0000, chosen = 0
# Bond XS1260712863: weight = 0.0000, chosen = 0
# Bond XS4173848348: weight = 0.0000, chosen = 0
# Bond XS7202310676: weight = 0.0000, chosen = 0
# Bond XS4066828003: weight = 0.0000, chosen = 0
# Bond XS8520382863: weight = 0.0000, chosen = 0
# Bond XS2442834346: weight = 0.0000, chosen = 0
# Bond XS8646426180: weight = 0.0000, chosen = 0
# Bond XS5678114452: weight = 0.0000, chosen = 0
# Bond XS7053068335: weight = 0.0000, chosen = 0
# Bond XS2562621378: weight = 0.0000, chosen = 0
# Bond XS6028087054: weight = 0.0000, chosen = 0
# Bond XS5454432238: weight = 0.0000, chosen = 0
# Bond XS1800455268: weight = 0.2249, chosen = 1
# Bond XS7574737148: weight = 0.0000, chosen = 0
# Bond XS3508043251: weight = 0.0000, chosen = 0
# Bond XS2481714670: weight = 0.0000, chosen = 0
# Bond XS5010485001: weight = 0.0000, chosen = 0
# Bond XS8204650445: weight = 0.0000, chosen = 0
# Bond XS2464442048: weight = 0.0000, chosen = 0
# Bond XS0230071761: weight = 0.0000, chosen = 0
# Bond XS5521054806: weight = 0.0000, chosen = 0
# Bond XS4412651511: weight = 0.0000, chosen = 0
# Bond XS1213850762: weight = 0.0000, chosen = 0
# Bond XS0437003741: weight = 0.0000, chosen = 0
# Bond XS5412866573: weight = 0.0000, chosen = 0
# Bond XS7378221224: weight = 0.0000, chosen = 0
# Bond XS4154504810: weight = 0.0000, chosen = 0
# Bond XS8885703070: weight = 0.0000, chosen = 0
# Bond XS2375671726: weight = 0.0000, chosen = 0
# Bond XS2615228646: weight = 0.0000, chosen = 0
# Bond XS8065803832: weight = 0.0000, chosen = 0
# Bond XS8135177028: weight = 0.0000, chosen = 0
# Bond XS4531754804: weight = 0.0000, chosen = 0
# Bond XS5455637686: weight = 0.0000, chosen = 0
# Bond XS2274375133: weight = 0.0000, chosen = 0
# Bond XS5507528172: weight = 0.0000, chosen = 0
# Bond XS4553230300: weight = 0.0000, chosen = 0
# Bond XS5432051746: weight = 0.0000, chosen = 0
# Bond XS1713048087: weight = 0.0000, chosen = 0
# Bond XS5620414781: weight = 0.0000, chosen = 0
# Bond XS2207578424: weight = 0.0000, chosen = 0
# Bond XS4423881776: weight = 0.0000, chosen = 0
# Bond XS7250608006: weight = 0.0000, chosen = 0
# Bond XS1477262552: weight = 0.0000, chosen = 0
# Bond XS6273036358: weight = 0.0000, chosen = 0
# Bond XS0460351405: weight = 0.0000, chosen = 0
# Bond XS5373774312: weight = 0.0000, chosen = 0
# Bond XS2334375576: weight = 0.0000, chosen = 0
# Bond XS7180733474: weight = 0.0000, chosen = 0
# Bond XS7085278560: weight = 0.0000, chosen = 0
# Bond XS4435680562: weight = 0.0000, chosen = 0
# Bond XS7484838482: weight = 0.0000, chosen = 0
# Bond XS3851611025: weight = 0.0000, chosen = 0
# Bond XS7863547005: weight = 0.0000, chosen = 0
# Bond XS1406038035: weight = 0.0000, chosen = 0
# Bond XS5706062720: weight = 0.0000, chosen = 0
# Bond XS7210211501: weight = 0.0000, chosen = 0
# Bond XS5230766221: weight = 0.0000, chosen = 0
# Bond XS0661670862: weight = 0.0000, chosen = 0
# Chosen bonds: ['XS1044688222', 'XS1800455268']
# Weights of chosen bonds: [0.7751250000000001, 0.22487499999999996]
